# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import string
import time

nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# Function to scrape homepage and extract article links
def get_article_links():
    url = "https://www.fox5dc.com/"
    response = requests.get(url)
    if response.status_code != 200:
        print("Failed to retrieve homepage.")
        return []
    soup = BeautifulSoup(response.text, 'html.parser')
    links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if re.search(r'/news/.+', href):
            full_url = href if href.startswith('http') else f'https://www.fox5dc.com{href}'
            links.append(full_url)
    return list(set(links))

# scrape article function
def scrape_article(url):
    try:
        response = requests.get(url)
        if response.status_code != 200:
            print("Failed to fetch:", url)
            return None
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # extract the title
        title_tag = soup.find('h1')
        title = title_tag.get_text(strip=True) if title_tag else "No Title"
        
        # extract article text 
        paragraphs = soup.find_all('p')
        text = " ".join(p.get_text(strip=True) for p in paragraphs)
        return {"url": url, "title": title, "text": text}
    except Exception as e:
        print("Error scraping", url, ":", e)
        return None

# get links from homepage
article_links = get_article_links()
print("Found {} article links.".format(len(article_links)))

# Scrape each article and store results in a list
articles = []
for url in article_links:
    print("Scraping:", url)
    article = scrape_article(url)
    if article:
        articles.append(article)
    time.sleep(1)

print("Scraped {} articles.".format(len(articles)))


df = pd.DataFrame(articles)

# extract topics using TF-IDF

vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
tfidf_matrix = vectorizer.fit_transform(df['text'])
feature_names = vectorizer.get_feature_names_out()

def get_top_keywords(tfidf_row, top_n=5):
    sorted_indices = tfidf_row.toarray().flatten().argsort()[::-1]
    top_indices = sorted_indices[:top_n]
    return [feature_names[i] for i in top_indices]

# new column for topics 
df['topics'] = [", ".join(get_top_keywords(tfidf_matrix[i])) for i in range(tfidf_matrix.shape[0])]


output_csv = "fox5_articles.csv"
df.to_csv(output_csv, index=False)
# Out:
# [nltk_data] Downloading package punkt to /home/mpritch1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/mpritch1/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Found 60 article links.
# Scraping: https://www.fox5dc.com/news/61-year-old-good-samaritan-shot-killed-off-duty-fbi-agent-stafford-county-police
# Scraping: https://www.fox5dc.com/news/nih-research-cuts-impact-medical-advancements
# Scraping: https://www.fox5dc.com/news/dmv-leaders-share-resources-federal-job-cuts-continue
# Scraping: https://www.fox5dc.com/news/montgomery-county-community-pushing-back-plan-open-rehab-facility-near-elementary-school
# Scraping: https://www.fox5dc.com/news/elon-musk-postal-service-amtrak-privatized
# Scraping: https://www.fox5dc.com/news/new-dolly-parton-song-carl-dean-tribute
# Scraping: https://www.fox5dc.com/news/spacex-starship-explodes-during-8th-flight-test-video
# Scraping: https://www.fox5dc.com/news/ceos-tariff-price-hikes-full-list
# Scraping: https://www.fox5dc.com/news/2-dozen-displaced-montgomery-village-townhome-fire
# Scraping: https://www.fox5dc.com/news/trump-sign-executive-order-take-aim-public-service-loan-forgiveness
# Scraping: https://www.fox5dc.com/news/trump-administration-urges-dc-leaders-focus-safety-security
# Scraping: https://www.fox5dc.com/news/trump-speech-congress-full-transcript
# Scraping: https://www.fox5dc.com/news/fcps-looking-expand-cell-phone-free-education
# Scraping: https://www.fox5dc.com/news/united-states-international-affairs-poll-2025
# Scraping: https://www.fox5dc.com/news/sun-country-minneapolis-diverted-update
# Scraping: https://www.fox5dc.com/news/new-mexico-measles
# Scraping: https://www.fox5dc.com/news/movies-to-watch-mickey-17-post-credits-scene-anora
# Scraping: https://www.fox5dc.com/news/dc-weather-first-70-degree-temps-2025-expected-next-week
# Scraping: https://www.fox5dc.com/news/jobs-report-february-2025
# Scraping: https://www.fox5dc.com/news/security-guard-charged-murder-after-deadly-hyattsville-mcdonalds-shooting
# Scraping: https://www.fox5dc.com/news/mn-man-girdwood-avalance
# Scraping: https://www.fox5dc.com/news/tony-toni-tone-guitarist-dwayne-wiggins-oakland-dies-at-64
# Scraping: https://www.fox5dc.com/news/washington-nationals-offering-free-tickets-current-former-federal-workers
# Scraping: https://www.fox5dc.com/news/maryland-drivers-illegally-registering-vehicles-virginia-costing-state-millions
# Scraping: https://www.fox5dc.com/news/californias-gavin-newsom-opposes-trans-athletes-womens-sports-splitting-progressives
# Scraping: https://www.fox5dc.com/news/map-best-time-to-list-your-home-zillow
# Scraping: https://www.fox5dc.com/news/family-dca-plane-crash-victim-files-250m-claim-against-us-army-faa
# Scraping: https://www.fox5dc.com/news/fox-news-sunday-with-shannon-bream
# Scraping: https://www.fox5dc.com/news/nearly-7ft-teen-baba-oladotun-turns-heads-nations-top-ranked-sophomore
# Scraping: https://www.fox5dc.com/news/2-teens-charged-armed-home-invasion-2-kids-called-911-from-inside-home-police
# Scraping: https://www.fox5dc.com/news/andrew-cross-youtube-creator-dies
# Scraping: https://www.fox5dc.com/news/adnan-syed-will-not-serve-additional-prison-time-judge-rules
# Scraping: https://www.fox5dc.com/news/congress-rep-al-green-censure-president-donald-trump-speech
# Scraping: https://www.fox5dc.com/news/gene-hackman-death-press-conference-march-2025
# Scraping: https://www.fox5dc.com/news/dc-plane-crash-pilots-grieving-father-calls-out-government-air-regulations
# Scraping: https://www.fox5dc.com/news/brad-sigmon-death-row-inmate-be-executed-firing-squad-1st-us-15-years
# Scraping: https://www.fox5dc.com/news/what-does-mean-be-censured
# Scraping: https://www.fox5dc.com/news/trump-auto-tariffs-where-things-stand
# Scraping: https://www.fox5dc.com/news/social-security-workforce-layoffs-employees-banned-news-websites
# Scraping: https://www.fox5dc.com/news/trump-no-tax-tips-overtime-address-congress
# Scraping: https://www.fox5dc.com/news/maryland-assisted-living-facility-employee-arrested-drug-distribution-police
# Scraping: https://www.fox5dc.com/news/dysentery-outbreak-oregon-leaves-least-40-sickened-what-know
# Scraping: https://www.fox5dc.com/news/people-say-they-never-had-covid-study
# Scraping: https://www.fox5dc.com/news/some-synthetic-hair-brands-contain-carcinogens-lead-other-harmful-chemicals-study-finds
# Scraping: https://www.fox5dc.com/news/maryland-men-detained-gunpoint-after-unknowingly-renting-stolen-car-turo
# Scraping: https://www.fox5dc.com/news/trump-postpones-tariffs-goods-mexico-month
# Scraping: https://www.fox5dc.com/news/faa-revising-air-traffic-control-tower-staffing-rules-dca-report
# Scraping: https://www.fox5dc.com/news/trump-doge-dividend-checks-status-who-could-qualify-payment-happens
# Scraping: https://www.fox5dc.com/news/celebrity-deaths-2025-list
# Scraping: https://www.fox5dc.com/news/pope-francis-health-vatican-update-ash-wednesday
# Scraping: https://www.fox5dc.com/news/american-airlines-jet-aborts-landing-dca-avoid-runway-collision
# Scraping: https://www.fox5dc.com/news/dc-homeless-encampments-cleared-out
# Scraping: https://www.fox5dc.com/news/washington-nationals-baltimore-orioles-masn-dispute
# Scraping: https://www.fox5dc.com/news/legacy-ice-honor-dc-plane-crash-victims
# Scraping: https://www.fox5dc.com/news/pentagon-dei-image-removal
# Scraping: https://www.fox5dc.com/news/spacex-starship-test-ends-explosion-off-floridas-coast-faa-orders-ground-stops-multiple-airports
# Scraping: https://www.fox5dc.com/news/what-is-hantavirus-pulmonary-syndrome
# Scraping: https://www.fox5dc.com/news/dj-daniel-cancer-secret-service-trump-speech-reaction
# Scraping: https://www.fox5dc.com/news/legacy-ice-honors-victims-dca-plane-crash-emotional-tribute
# Scraping: https://www.fox5dc.com/news/alabama-man-arrested-double-murder-virginia-couple-police
# Scraped 60 articles.
